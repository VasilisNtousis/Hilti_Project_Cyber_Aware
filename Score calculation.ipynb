# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # Read Excelfiles
# ## Phishing report

# %% [markdown]
# ### In order for this to work, save all reports in the Data folder

# %%
xl_file = pd.ExcelFile('Data/DataPhishingReport.xlsx', engine='openpyxl')

# %%
# Read every sheet within the spreadsheet
dfs = {sheet_name: xl_file.parse(sheet_name) for sheet_name in xl_file.sheet_names}

# %%
# Exclude the sheet that is named 'Blank' as it does not seem to be useful for the data analysis
for df_name, df_content in dfs.items():
    if df_name != 'Blank':
        df_content['Type'] = df_name

# %%
real_phishing = dfs['RealPhishing']
attachments = dfs['Attachments']
internal = dfs['Internal Phishing']
spam = dfs['Spam']

# %%
# Standardize fields across all sheets
real_phishing['Sender'] = real_phishing['UserID']
real_phishing = real_phishing.rename(columns={"Date": "Received"})
real_phishing = real_phishing.drop(['Unnamed: 1', 'Unnamed: 2', 'UserID', 'More than 1 recipient', 'TicketNr'], axis=1)

# %%
sender = real_phishing.pop('Sender')
subject = real_phishing.pop('Subject')
real_phishing.insert(0, 'Subject', subject)
real_phishing.insert(2, 'Sender', sender)
real_phishing.head()
# Out:
#                                              Subject   Received      Sender  \
# 0  Phishing Email Report: Delivery restriction no... 2020-09-14   9903746.0
# 1      Phishing Email Report: ProposaIs from TORROJA 2020-09-14   9918069.0
# 2  Phishing Email Report: [MARKETING] Tyler, Your... 2020-09-14  10823974.0
# 3  Phishing Email Report: Your mindy.flaherty@hil... 2020-09-14   9938174.0
# 4  Phishing Email Report: Your mindy.flaherty@hil... 2020-09-15   9938174.0
#
#            Type
# 0  RealPhishing
# 1  RealPhishing
# 2  RealPhishing
# 3  RealPhishing
# 4  RealPhishing

# %%
# Concatenate all sheets into one phishing report
phishing_report = pd.concat([real_phishing, attachments, internal, spam])

# %%
grouped = phishing_report.groupby(['Sender', 'Type']).count().copy().reset_index()

# %%
# Check for missing User IDs. This is the main information for us, so drop them (if there is not too many)
phishing_report.loc[phishing_report['Sender'].isnull()]
# Out:
#                                               Subject            Received  \
# 22  Phishing Email Report: 21 September, 2020, 𝚎Vo... 2020-09-22 00:00:00
# 26  Phishing Email Report: 22 September, 2020, 𝚎Vo... 2020-09-22 00:00:00
# 73  Phishing Email Report: Issues with the phone s... 2020-09-22 18:53:15
#
#     Sender          Type
# 22     NaN  RealPhishing
# 26     NaN  RealPhishing
# 73     NaN          Spam

# %%
# Enter indexes with missing values inside drop([])
phishing_report = phishing_report.drop([22, 26, 73]).copy()

# %%
# Make sure User IDs are formatted as integers
phishing_report['Sender'] = phishing_report['Sender'].astype(int)

# %%
grouped.columns
# Out:
# Index(['Sender', 'Type', 'Subject', 'Received'], dtype='object')

# %%
# Data exploration
grouped.loc[(grouped['Type'] == 'Spam') & (grouped['Received'] > 10)]
# Out:
#         Sender  Type  Subject  Received
# 30   9904608.0  Spam       12        12
# 31   9904646.0  Spam       12        12
# 40   9917492.0  Spam       13        13
# 93   9922294.0  Spam       21        21
# 102  9922778.0  Spam       18        18
# 159  9925734.0  Spam       11        11
# 176  9926897.0  Spam       32        32
# 203  9928743.0  Spam       53        53
# 279  9935944.0  Spam       14        14
# 289  9936746.0  Spam       37        37
# 298  9937207.0  Spam       12        12
# 316  9938078.0  Spam       35        35

# %% [markdown]
# ## Cybersecurity Awareness Training

# %%
training = pd.read_excel('Data/IT Security Awareness Global report.xlsx', engine='openpyxl')

# %% [markdown]
# ## There are a lot of columns in the report, not all are useful

# %%
training = training.drop(['Course specified approver', 'Username', 'FunctionalAreaCode', 'CostCenterName', 
                          'Time spent on test', 'Suspend data', 'Creator approver', 'Manager approver', 'Specified Approver', 'Approval date', 
                          'Community name', 'EmployeeGuid', 'SAPCentralPersonNumber', 'Email', 'Content ID', 'TradeAssignment(Attribute8)', 
                          'SalesOrganizationName', 'SalesOrganizationCode', 'Last login', 'Last activity'], axis=1)

# %%
# Calculate the difference between now and the date when the course was completed for "time passed since" score
import datetime
now = datetime.datetime.now().replace(microsecond=0)
diff = (now - training['Date course completed']).dt.days

# %%
training['Time passed since'] = diff

# %%
training['SCORM course status'].unique()
# Out:
# array(['passed', 'completed', 'not started', 'incomplete', 'failed'],
#       dtype=object)

# %%
# Drop users with missing valuable data
training = training.drop([18607, 18924, 22366, 22356, 24359, 24440, 25524, 26464, 28813, 29075, 29171, 29591, 30199, 31151, 32124])

# %%
# Reformat data
grouped_training = training.groupby(['Department', 'SCORM course status', 'Test score', 'User ID']).count().copy()

# %%
top_departments_low_score = training.loc[(training['Test score'] < 50) & (training['Test score'] > 0)].groupby('Department')['User ID'].count().reset_index().sort_values('User ID', ascending=False).copy()

# %%
# Some data exploration
top_departments_low_score
# Out:
#                    Department  User ID
# 0                    AREA 143        2
# 35          K Executive Board        2
# 10           Dayton Inventory        2
# 39                     ME Ost        2
# 41        MO FR Local Support        2
# ..                        ...      ...
# 25  Global Logistics Services        1
# 24             General Ledger        1
# 23        Finance  Operations        1
# 22                   FRANCE 1        1
# 75                 operations        1
#
# [76 rows x 2 columns]

# %%
training.loc[training['SCORM course status'].isin(['not started', 'failed', 'incomplete'])].groupby('Department')['User ID'].count().reset_index().sort_values('User ID', ascending=False).copy()
# Out:
#                                  Department  User ID
# 1481                                  Sales      111
# 1088              ODO Operations  Processes      108
# 287         DSG Software Process Governance       94
# 1256                  P88 Tool Production 1       62
# 1291                             Production       53
# ...                                     ...      ...
# 961   META Talent Aquisition and Management        1
# 954                           ME North West        1
# 950                                     MCS        1
# 949                             MCC Digital        1
# 2204                                 ventas        1
#
# [2205 rows x 2 columns]

# %%
# Completed should only mean successful completion. If they failed, then change the status to 'failed'
training.loc[(training['SCORM course status'] == 'completed') & (training['Test score'] < 80), 'SCORM course status'] = 'failed'

# %% [markdown]
# ## Phishing simulation test

# %%
simulation = pd.read_excel('FirstPhishingSimulation_Results.xlsx', engine='openpyxl')

# %%
# Drop unnecessary columns
simulation = simulation.drop(['Received Emails', 'Send Email', 'Recipients', 'Time Zone', 'Clicked Link', 'Completed Form', 'Visited Feedback Page', 'Department2', 'Total Education Time', 'Department3'], axis=1)

# %%
simulation.loc[(simulation['Opened Attachment']==1) & (simulation['Visited Feedback Page True False'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Scenario, UserID, Language, Opened Emails, Reported Emails, Viewed Images, Clicked Link True/False, Opened Attachment, Completed Form True False, Visited Feedback Page True False, IsoCode, Department1, Company, Position, Department]
# Index: []

# %%
# Deducting some missing data
simulation.loc[simulation['Department1'].isnull(), 'Department1'] = simulation['Company']
simulation.loc[simulation['IsoCode'].isnull(), 'IsoCode'] = simulation['Company']

# %%
simulation.loc[(simulation['IsoCode'].isnull()) & (simulation['Department1'].isnull()) & (simulation['IsoCode'].isnull())].index
# Out:
# Int64Index([  105,  1731,  4424,  4491,  4591,  7914, 10928, 11231, 11496,
#             12077, 13469, 16586, 16587, 19067, 21501, 22236, 22770, 22784,
#             27809, 27844],
#            dtype='int64')

# %%
# Drop rows with missing values that cannot be deducted
simulation = simulation.drop([105, 1731, 4424, 4491, 4591, 7914, 10928, 11231, 11496, 12077, 13469, 16586, 16587, 19067, 21501, 22236, 22770, 22784, 27809, 27844])

# %%
# 161 people failed the test and reported the simulation email
simulation.loc[(simulation['Completed Form True False'] == 1) & (simulation['Reported Emails'] == 1)]
# Out:
#                   Scenario    UserID Language  Opened Emails  Reported Emails  \
# 13     Nov 24 Phishing Sim  10690548  English              1                1
# 18     Nov 24 Phishing Sim   9940169  English              1                1
# 501    Nov 24 Phishing Sim   9935354  English              1                1
# 781    Nov 24 Phishing Sim  10354058  English              1                1
# 889    Nov 24 Phishing Sim   9935126  English              1                1
# ...                    ...       ...      ...            ...              ...
# 30868  Nov 24 Phishing Sim  11263702  English              1                1
# 30976  Nov 24 Phishing Sim  10647914  English              1                1
# 31087  Nov 24 Phishing Sim   9927510  English              1                1
# 31449  Nov 24 Phishing Sim  10893500  English              1                1
# 31458  Nov 24 Phishing Sim   9943491  English              1                1
#
#        Viewed Images  Clicked Link True/False  Opened Attachment  \
# 13                 1                        1                  0
# 18                 1                        1                  0
# 501                0                        1                  0
# 781                1                        1                  0
# 889                0                        1                  0
# ...              ...                      ...                ...
# 30868              0                        1                  0
# 30976              1                        1                  0
# 31087              1                        1                  0
# 31449              1                        1                  0
# 31458              1                        1                  0
#
#        Completed Form True False  Visited Feedback Page True False IsoCode  \
# 13                             1                                 1      IN
# 18                             1                                 1      IN
# 501                            1                                 1      MY
# 781                            1                                 1      LI
# 889                            1                                 1      IN
# ...                          ...                               ...     ...
# 30868                          1                                 1      IN
# 30976                          1                                 1      CN
# 31087                          1                                 1      SA
# 31449                          1                                 1      CN
# 31458                          1                                 1      CN
#
#                            Department1                         Company  \
# 13                               sales           Hilti India Pvt. Ltd.
# 18                               sales           Hilti India Pvt. Ltd.
# 501    info.technology / info.services  Hilti Asia IT Services Sdn Bhd
# 781       product portfolio management                        hilti ag
# 889                 general management       hilti manufacturing india
# ...                                ...                             ...
# 30868                          finance           Hilti India Pvt. Ltd.
# 30976                    manufacturing           Hilti (Shanghai) Ltd.
# 31087                            sales              hilti saudi arabia
# 31449     product portfolio management           Hilti (Shanghai) Ltd.
# 31458                    manufacturing           Hilti (Shanghai) Ltd.
#
#                                    Position                     Department
# 13            Sr. Technical Account Manager  Area Sales - Gen East Central
# 18                      Key Account Manager        Area Sales - EI South 2
# 501    Head of Core Infrastructure Services          FII IT Infrastructure
# 781                          Supply Manager        XV Supply Management DX
# 889                 Chief Technical Officer       ZEC Diamond Insert Tools
# ...                                     ...                            ...
# 30868                  Sr. Business Analyst         FCC Business Reporting
# 30976         Management Associate-Logistic                  P88 Logistics
# 31087          Head of Key Project Managers                    KA-KP Sales
# 31449                        Supply Manager       HSA Supply-AlliedInserts
# 31458                   Mechanical Engineer    TWTC Mechanical Engineering
#
# [161 rows x 15 columns]

# %%
simulation.shape
# Out:
# (31666, 15)

# %%
# More country deduction
simulation.loc[simulation['IsoCode'] == 'Hilti Jordan', 'IsoCode'] = 'JO'
simulation = simulation.drop([9584, 15063, 17155, 29028])
simulation.loc[simulation['IsoCode'].str.len() > 2, 'IsoCode'] = ''
sim_countries = dict(zip(simulation['UserID'], simulation['IsoCode']))
user_countries = dict(zip(training['User ID'], training['CountryISOCode']))

# %% [markdown]
# ## Preprocess data for the combined report

# %%
# Get ids from every report
report_ids = np.array(phishing_report['Sender'])
training_ids = np.array(training['User ID'])
simulation_ids = np.array(simulation['UserID'])

# %%
# Only save unique ids
unique_ids = np.unique(np.concatenate((report_ids, training_ids, simulation_ids), 0))

# %% [markdown]
# ### Get relevant data from each report by User ID

# %%
users_failed_sim = dict(zip(simulation['UserID'], simulation['Completed Form True False']))

# %%
passed_training = dict(zip(training['User ID'], training['SCORM course status']))

# %%
time_since_training = dict(zip(training['User ID'], training['Time passed since']))

# %%
training_score = dict(zip(training['User ID'], training['Test score']))

# %%
report_anything = phishing_report['Sender']

# %%
users_sim_1 = dict(zip(simulation['UserID'], simulation['Viewed Images']))
users_sim_2 = dict(zip(simulation['UserID'], simulation['Clicked Link True/False']))
users_sim_3 = dict(zip(simulation['UserID'], simulation['Opened Attachment']))

# %%
users_report_sim = dict(zip(simulation['UserID'], simulation['Reported Emails']))

# %%
users_watch_sim = dict(zip(simulation['UserID'], simulation['Visited Feedback Page True False']))

# %%
'''
Users completed form (0: did not submit data in simulation, 1: submitted data), 
passed training (0: passed/completed, 1: not passed/completed)
reported anything via phishing report button: (0: no, 1: yes)
test score
time since training: 1 = low(less than 6 months), 2 = medium(more than 6 months less than 1.5), 3 = high(more than 1.5 years)
did user view images in simulation (0: no, 1: yes)
did user click link in simulation (0: no, 1: yes)
did user open attachment in simulation (0: no, 1: yes)
did user report: -1 yes, +1 no
did user watch feedback - (0: no, -1: yes)
'''
# Out:
# '\nUsers completed form (0: did not submit data in simulation, 1: submitted data), \npassed training (0: passed/completed, 1: not passed/completed)\nreported anything via phishing report button: (0: no, 1: yes)\ntest score\ntime since training: 1 = low(less than 6 months), 2 = medium(more than 6 months less than 1.5), 3 = high(more than 1.5 years)\ndid user view images in simulation (0: no, 1: yes)\ndid user click link in simulation (0: no, 1: yes)\ndid user open attachment in simulation (0: no, 1: yes)\ndid user report: -1 yes, +1 no\ndid user watch feedback - (0: no, -1: yes)\n'

# %% [markdown]
# ### Append all data into a dictionary, where key is a user id and values are each value for each feature

# %%
temp = {}
for uid in unique_ids:
    try:
        temp[uid] = [users_failed_sim[uid]]
    except KeyError:
        temp[uid] = [0]

# %%
for uid in unique_ids:
    try:
        if passed_training[uid] == 'passed' or passed_training[uid] == 'completed':
            temp[uid].append(0)
        else:
            temp[uid].append(1)
    except KeyError:
        temp[uid].append(1)

# %%
for uid in unique_ids:
    if uid in phishing_report['Sender']:
        temp[uid].append(1)
    else:
        temp[uid].append(0)

# %%
for uid in unique_ids:
    try:
        temp[uid].append(training_score[uid])
    except KeyError:
        temp[uid].append(0)

# %%
low = 183
high = 548

# %%
for k,v in time_since_training.items():
    if str(v) == 'nan':
        metric = 3
    elif v <= low:
        metric = 1
    elif v > low and v <= high:
        metric = 2
    else:
        metric = 3
    time_since_training[k] = metric

# %%
for uid in unique_ids:
    try:
        temp[uid].append(time_since_training[uid])
    except KeyError:
        temp[uid].append(3)

# %%
for uid in unique_ids:
    for d in [users_sim_1, users_sim_2, users_sim_3]:
        try:
            temp[uid].append(d[uid])
        except KeyError:
            temp[uid].append(0)

# %%
for uid in unique_ids:
    try:
        if users_report_sim[uid] == 1 and temp[uid][0] == 0 and temp[uid][5] == 0 and temp[uid][6] == 0 and temp[uid][7] == 0:
            temp[uid].append(-1)
        else:
            temp[uid].append(1)
    except KeyError:
        temp[uid].append(1)

# %%
for uid in unique_ids:
    try:
        if users_watch_sim[uid] == 1:
            temp[uid].append(-1)
        else:
            temp[uid].append(0)
    except KeyError:
        temp[uid].append(0)

# %%
green = 4
yellow = 7
red = 9

# %%
# End result
temp
# Out:
# {6677201: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  6812989: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  6812994: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  7469741: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  8577487: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  8819324: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  8924410: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  8927352: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  8941913: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9374413: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9374414: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9374415: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9374416: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9374561: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9399474: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9678721: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9684128: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9688411: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9688412: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9751070: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9786655: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9795814: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9796006: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9796009: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9796407: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9796558: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9796560: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9796562: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9797178: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9797285: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9797404: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9797406: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9797408: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9798498: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9799743: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9800580: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9800587: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9803409: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9806126: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9806128: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9806132: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9806134: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9806135: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9813237: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9813238: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9813239: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9813240: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9813242: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9813243: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9813244: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9813245: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9813246: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9813327: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9814747: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9814748: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9814749: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9814750: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9814752: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9814753: [0, 1, 0, 80.0, 3, 0, 0, 0, 1, 0],
#  9814754: [1, 1, 0, 0.0, 3, 1, 1, 0, 1, -1],
#  9814755: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  
[0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820771: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9820773: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9820774: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9820781: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9820783: [0, 0, 0, 100.0, 1, 0, 1, 0, 1, -1],
#  9820784: [0, 1, 0, 0.0, 3, 0, 0, 0, 1, 0],
#  9820785: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820786: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9820787: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9820788: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820789: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9820791: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9820794: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820796: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820797: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9820798: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9820799: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9820804: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9820807: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9820808: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9820810: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9820814: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9820816: [1, 0, 0, 100.0, 1, 0, 1, 0, 1, -1],
#  9820818: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9820820: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9821264: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9821266: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9825431: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9825440: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9825443: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9825444: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9825445: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9825447: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9826343: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9826345: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9826347: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9826350: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9826566: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9826823: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9828791: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9828801: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9828802: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9828923: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9829436: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9829886: [1, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9830270: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9831654: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9831656: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9832449: [0, 1, 0, 70.0, 3, 0, 1, 0, 1, 0],
#  9833308: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9837685: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9837695: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9838758: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9838760: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9838769: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9840862: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9840869: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9841526: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842034: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9842035: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842036: [0, 1, 0, nan, 3, 0, 1, 0, 1, -1],
#  9842037: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842038: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9842039: [0, 1, 0, 50.0, 3, 0, 1, 0, 1, 0],
#  9842040: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9842041: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842043: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9842044: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842045: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9842047: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842048: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9842049: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842050: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9842051: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9842052: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9842053: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9842054: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9842838: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9845743: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9847725: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9848264: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9848338: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9856340: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9856341: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9856342: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9856343: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9856344: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9856345: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9856346: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9856347: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9856348: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9856447: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9860085: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9864219: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9864504: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9864506: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9864511: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9864514: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9864540: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9864541: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9864542: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9864543: [1, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9864545: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9864547: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9865131: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9865259: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9865758: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9865783: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9867904: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9867908: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9867913: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9867914: [1, 1, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9867918: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9867919: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9867922: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9868504: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9870635: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9870637: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9870638: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9870640: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9870641: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9870642: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9870643: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9870644: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9870645: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9870648: [0, 1, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9870649: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9871779: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9872015: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9872017: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9872024: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9872025: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9872029: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9872030: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9872031: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9872033: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9872471: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9872475: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9872479: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9872766: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9872768: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9872773: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9872775: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9872785: [1, 1, 0, 80.0, 3, 1, 1, 0, 1, -1],
#  9872789: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9872794: [1, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9874793: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9874795: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9879949: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9880041: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9880268: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9880276: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9880279: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9880447: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9888552: [1, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9891532: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9891592: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9892466: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9892469: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9892470: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9892473: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  9892474: [1, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9893335: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9893543: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9894157: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9894159: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9894160: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9894162: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9894163: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9894164: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9894165: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9894166: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9894167: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9894171: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9894172: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9894173: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9894174: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9894560: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9894665: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9898904: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9898906: [1, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9898908: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  9898909: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9898913: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9898916: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9898917: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9898919: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9898920: [1, 1, 0, nan, 3, 0, 1, 0, 1, -1],
#  9898921: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9899142: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9899144: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9899147: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899150: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9899152: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899153: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899162: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899164: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899165: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899166: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899167: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899168: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899170: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899171: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9899174: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899175: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899176: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899185: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899190: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899192: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899193: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9899194: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899195: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899200: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9899201: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9899204: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899205: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899207: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899208: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899209: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899210: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  9899212: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899219: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899222: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9899228: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9899229: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9899232: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9899234: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9899235: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899240: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9899241: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9899243: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899245: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899247: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9899251: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9899253: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899254: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899256: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899261: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899262: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899264: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899269: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9899271: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9899273: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9899275: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9899276: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9899280: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899291: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899292: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9899295: [0, 0, 0, 100.0, 1, 0, 0, 0, 1, 0],
#  9899981: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9899983: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9899984: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900165: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900166: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9900169: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9900170: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900171: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900172: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900175: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900177: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900178: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9900182: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900183: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900185: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900186: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9900188: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900189: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900194: [0, 1, 0, 50.0, 3, 1, 0, 0, 1, 0],
#  9900195: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  9900197: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900199: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9900201: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900203: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900206: [0, 1, 0, nan, 3, 0, 1, 0, 1, -1],
#  9900209: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900211: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900212: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900214: [1, 1, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9900218: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900219: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900220: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9900223: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9900225: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900226: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900229: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900231: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900233: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900236: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900238: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900239: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900242: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900244: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900245: [1, 0, 0, 100.0, 1, 0, 1, 0, 1, -1],
#  9900248: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900249: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9900250: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900253: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900255: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900256: [1, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9900258: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9900259: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9900260: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9900261: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900262: [0, 1, 0, 0.0, 3, 0, 0, 0, 1, 0],
#  9900264: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900266: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9900267: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900268: [0, 1, 0, nan, 3, 0, 1, 0, 1, 0],
#  9900272: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900273: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9900274: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9900275: [0, 1, 0, nan, 3, 0, 1, 0, 1, -1],
#  9900276: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900281: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9900283: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900284: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9900287: [0, 1, 0, nan, 3, 1, 1, 0, 1, 0],
#  9900288: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9900291: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900292: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900293: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900294: [0, 1, 0, 80.0, 3, 1, 1, 0, 1, -1],
#  9900295: [0, 1, 0, nan, 3, 0, 1, 0, 1, 0],
#  9900297: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900299: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900301: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900302: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900303: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900307: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900308: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900309: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900310: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9900312: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900314: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900320: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900321: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900322: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900323: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900324: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900326: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900333: [0, 0, 0, 100.0, 1, 0, 0, 0, 1, 0],
#  9900336: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900337: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900339: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900341: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900345: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900350: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900354: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, 0],
#  9900363: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900368: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900374: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9900375: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900381: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900384: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900385: [0, 1, 0, 0.0, 3, 0, 0, 0, 1, 0],
#  9900386: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900390: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900391: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900392: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900394: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900395: [1, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9900405: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900408: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900417: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900468: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9900469: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900478: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900489: [0, 0, 0, 100.0, 3, 0, 0, 0, -1, 0],
#  9900492: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900495: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900496: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900497: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900500: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900506: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9900507: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9900508: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9900509: [0, 0, 0, 100.0, 2, 0, 0, 0, -1, 0],
#  9900514: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900516: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900517: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900521: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900528: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9900531: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900538: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9900541: [0, 1, 0, 50.0, 3, 1, 0, 0, 1, 0],
#  9900543: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9900549: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9900550: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900552: [0, 1, 0, 0.0, 3, 0, 0, 0, 1, 0],
#  9900558: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9900559: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9900561: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900565: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9900577: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9900578: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9900581: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9900583: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9900831: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  
[1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9904043: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904045: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904046: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904050: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904052: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9904053: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904054: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904057: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904061: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904064: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904065: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904069: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, -1],
#  9904071: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904072: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904079: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9904087: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904088: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9904090: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9904094: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904100: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904101: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904102: [0, 1, 0, nan, 3, 1, 1, 0, 1, -1],
#  9904105: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9904107: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904109: [0, 1, 0, nan, 3, 0, 0, 0, -1, 0],
#  9904111: [0, 0, 0, 100.0, 2, 0, 1, 0, 1, 0],
#  9904112: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904113: [0, 0, 0, 100.0, 1, 1, 1, 0, 1, -1],
#  9904116: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9904120: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904122: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904124: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904126: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904131: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904135: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904136: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904138: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904139: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9904140: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904142: [1, 0, 0, 100.0, 2, 1, 1, 0, 1, -1],
#  9904147: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904150: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904151: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904154: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904156: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904176: [0, 0, 0, 100.0, 1, 1, 0, 0, 1, 0],
#  9904184: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9904186: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904189: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904190: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904193: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904194: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, -1],
#  9904195: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904201: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904202: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904215: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904216: [1, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904225: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904226: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9904232: [0, 0, 0, 100.0, 3, 1, 0, 0, 1, 0],
#  9904233: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9904236: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904241: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9904245: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904248: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904253: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904254: [0, 1, 0, nan, 3, 0, 0, 0, 1, 0],
#  9904259: [0, 0, 0, 100.0, 2, 1, 1, 0, 1, 0],
#  9904260: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904263: [0, 0, 0, 100.0, 3, 0, 0, 0, 1, 0],
#  9904269: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, 0],
#  9904270: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904273: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904274: [0, 0, 0, 100.0, 2, 1, 0, 0, 1, 0],
#  9904275: [0, 0, 0, 100.0, 3, 0, 1, 0, 1, 0],
#  9904278: [0, 0, 0, 100.0, 3, 1, 1, 0, 1, -1],
#  9904279: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9904285: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  9904286: [0, 1, 0, nan, 3, 1, 0, 0, 1, 0],
#  9904288: [0, 0, 0, 100.0, 2, 0, 0, 0, 1, 0],
#  ...}

# %%
# Calculate the score by summing up all values
for keys, values in temp.items():
    risk_score = values[4] + values[1] + values[0] + values[5] + values[6] + values[7] + values[8] + values[9]
    temp[keys].append(risk_score)

# %% [markdown]
# # The final result

# %%
risk_df = pd.DataFrame(columns=['User ID', 'Completed sim form', 'Passed training', 'Used phishing button', 'Test score', 'Time since training', 'Viewed images', 'Clicked link', 'Opened attachment', 'Reported sim', 'Watched feedback', 'Individual Risk Score'])

# %%
# Append data into the new dataframe
for k,v in temp.items():
    tmp = {
        'User ID': k, 
        'Completed sim form': v[0], 
        'Passed training': v[1], 
        'Used phishing button': v[2], 
        'Test score': v[3], 
        'Time since training': v[4], 
        'Viewed images': v[5], 
        'Clicked link': v[6], 
        'Opened attachment': v[7], 
        'Reported sim': v[8], 
        'Watched feedback': v[9], 
        'Individual Risk Score': v[10]
    }
    
    risk_df = risk_df.append(tmp, ignore_index=True)

# %%
# Format User ID as integer
risk_df['User ID'] = risk_df['User ID'].astype(int)

# %%
# Placeholder status
risk_df['Status'] = 'green'

# %%
# Set the correct status
risk_df.loc[(risk_df['Individual Risk Score'] > green) & (risk_df['Individual Risk Score'] <= yellow), 'Status'] = 'yellow'
risk_df.loc[(risk_df['Individual Risk Score'] > yellow) & (risk_df['Individual Risk Score'] <= red), 'Status'] = 'red'

# %%
risk_df['Status'].value_counts()
# Out:
# yellow    17581
# green     14730
# Name: Status, dtype: int64

# %%
risk_df.head()
# Out:
#    User ID  Completed sim form  Passed training  Used phishing button  \
# 0  6677201                 0.0              0.0                   0.0
# 1  6812989                 0.0              0.0                   0.0
# 2  6812994                 0.0              0.0                   0.0
# 3  7469741                 0.0              0.0                   0.0
# 4  8577487                 1.0              0.0                   0.0
#
#    Test score  Time since training  Viewed images  Clicked link  \
# 0       100.0                  3.0            0.0           0.0
# 1       100.0                  3.0            0.0           0.0
# 2       100.0                  2.0            0.0           1.0
# 3       100.0                  3.0            0.0           0.0
# 4       100.0                  3.0            1.0           1.0
#
#    Opened attachment  Reported sim  Watched feedback  Individual Risk Score  \
# 0                0.0           1.0               0.0                    4.0
# 1                0.0           1.0               0.0                    4.0
# 2                0.0           1.0               0.0                    4.0
# 3                0.0           1.0               0.0                    4.0
# 4                0.0           1.0              -1.0                    6.0
#
#    Status
# 0   green
# 1   green
# 2   green
# 3   green
# 4  yellow

# %% [markdown]
# # More data exploration

# %%
# Total users in the dataset
n_users = risk_df.shape[0]
n_users
# Out:
# 32311

# %%
# How many passed the training, didn't fail the simulation and reported the simulation email
passed_not_click = risk_df.loc[(risk_df['Passed training'] == 0.0) & (risk_df['Reported sim'] == -1.0) & (risk_df['Clicked link'] == 0.0)]['User ID'].count()
passed_not_click
# Out:
# 466

# %%
percentage_actually_learned = (passed_not_click/n_users)*100
percentage_actually_learned
# Out:
# 1.4422332951626382

# %%
# Phishing report, break down by type
phishing_report['Type'].value_counts()
# Out:
# Spam                 720
# Internal Phishing    162
# RealPhishing          78
# Attachments           19
# Name: Type, dtype: int64

# %%
phishing_report['Sender'].unique().shape
# Out:
# (491,)

# %%
# How many unique users have reported anything
unique_used_button = (491/n_users)*100

# %%
# How many reported emails are actually real
reporting_accuracy = (78/979)*100

# %%
# Add a country field
risk_df.insert(1, 'Country', '')

# %%
for k,v in sim_countries.items():
    risk_df.loc[risk_df['User ID'] == k, 'Country'] = v

# %%
# Save the file
risk_df.to_csv('ind_scores.csv')

# %% [markdown]
# ### Save some interesting metrics

# %%
percentages = pd.DataFrame(columns=['Internalized', 'Used phishing report button', 'Phishing report accuracy', 'Average Individual Risk Score', 'Individual Risk Score std'])

# %%
data_dict = {
    'Internalized': round(percentage_actually_learned, 4), 
    'Used phishing report button': round(unique_used_button, 4), 
    'Phishing report accuracy': round(reporting_accuracy, 4),
    'Average Individual Risk Score': round(risk_df['Individual Risk Score'].mean(), 4), 
    'Individual Risk Score std': round(risk_df['Individual Risk Score'].std(), 4)
}

# %%
percentages = percentages.append(data_dict, ignore_index=True)

# %%
# Save the file
percentages.to_csv('percentages.csv')
